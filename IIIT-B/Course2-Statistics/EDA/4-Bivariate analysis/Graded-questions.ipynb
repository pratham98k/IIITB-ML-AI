# %%
#import the libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("EDA_census_new_one.csv")

# %%
df
# Out:
#      Table_Name  State_Code Distt_code                          Area_Name  \
# 0         C2308           0       Code                              INDIA
# 1         C2308           0        000                              INDIA
# 2         C2308           0        000                              INDIA
# 3         C2308           0        000                              INDIA
# 4         C2308           0        000                              INDIA
# ...         ...         ...        ...                                ...
# 3127      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3128      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3129      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3130      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3131      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
#
#      Total_Rural_Urban       Age_group  Total_Persons  Total_males  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Table_Name  State_Code Distt_code                          Area_Name  \
# 0         C2308           0       Code                              INDIA
# 1         C2308           0        000                              INDIA
# 2         C2308           0        000                              INDIA
# 3         C2308           0        000                              INDIA
# 4         C2308           0        000                              INDIA
# ...         ...         ...        ...                                ...
# 3127      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3128      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3129      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3130      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3131      C2308          35        000  State - ANDAMAN & NICOBAR ISLANDS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3132 entries, 0 to 3131
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Table_Name          3132 non-null   object
#  1   State_Code          3132 non-null   int64
#  2   Distt_code          3132 non-null   object
#  3   Area_Name           3132 non-null   object
#  4   Total_Rural_Urban   3132 non-null   object
#  5   Age_group           3132 non-null   object
#  6   Total_Persons       3132 non-null   int64
#  7   Total_males         3132 non-null   int64
#  8   Total_Females       3132 non-null   int64
#  9   Illiterate_Persons  3132 non-null   int64
#  10  Illiterate_Males    3132 non-null   int64
#  11  Illiterate_Females  3132 non-null   int64
#  12  Literate_Persons    3132 non-null   int64
#  13  Literate_Males      3132 non-null   int64
#  14  Literate_females    3132 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Table_Name', 'State_Code', 'Distt_code', 'Area_Name',
#        'Total_Rural_Urban', 'Age_group', 'Total_Persons', 'Total_males',
#        'Total_Females', 'Illiterate_Persons', 'Illiterate_Males',
#        'Illiterate_Females', 'Literate_Persons', 'Literate_Males',
#        'Literate_females', 'Unnamed: 15'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   Table_Name  State_Code Distt_code Area_Name Total_Rural_Urban Age_group  \
# 0      C2308           0       Code     INDIA             Total  All ages
# 1      C2308           0        000     INDIA             Total       0-6
# 2      C2308           0        000     INDIA             Total         7
# 3      C2308           0        000     INDIA             Total         8
# 4      C2308           0        000     INDIA             Total         9
#
#    Total_Persons  Total_males  Total_Females  Illiterate_Persons  \
# 0     1210854977    623270258      587584719           447216165
# 1      164515253     85752254       78762999           164515253
# 2       24826640     12903364       11923276             6748214
# 3       26968373     14061937       12906436             4131414
# 4       23424638     12214985       11209653             2491904
#
#    Illiterate_Males  Illiterate_Females  Literate_Persons  Literate_Males  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.barplot(data=df, x = df["Age_group"], y = "Literate_Persons")
# Out:
# <Axes: xlabel='Age_group', ylabel='Literate_Persons'>

# %%
df["Illiterate_Females"].value_counts()
# Out:
# Illiterate_Females
# 8       9
# 27      5
# 2       5
# 21      5
# 34      5
#        ..
# 271     1
# 3612    1
# 4662    1
# 5663    1
# 25      1
# Name: count, Length: 2859, dtype: int64

# %%
df[df["Area_Name"] == "INDIA"] & df[df["Age_group"] == "20-24"
# Out:
#   Cell In[37], line 1
#     df[df["Area_Name"] == "INDIA"] & df[df["Age_group"] == "20-24"
#                                                                   ^
# SyntaxError: incomplete input

# %%
plt.figure(figsize=(20,20))
sns.boxplot(data=df, x = df["Age_group"], y = "Literate_Persons")
# Out:
# <Axes: xlabel='Age_group', ylabel='Literate_Persons'>

# %%
df.columns
# Out:
# Index(['Table_Name', 'State_Code', 'Distt_code', 'Area_Name',
#        'Total_Rural_Urban', 'Age_group', 'Total_Persons', 'Total_males',
#        'Total_Females', 'Illiterate_Persons', 'Illiterate_Males',
#        'Illiterate_Females', 'Literate_Persons', 'Literate_Males',
#        'Literate_females', 'Unnamed: 15'],
#       dtype='object')

# %%
df["Area_Name"].value_counts()
# Out:
# Area_Name
# INDIA                                87
# State - JAMMU & KASHMIR              87
# State - JHARKHAND                    87
# State - ODISHA                       87
# State - CHHATTISGARH                 87
# State - MADHYA PRADESH               87
# State - GUJARAT                      87
# State - DAMAN & DIU                  87
# State - DADRA & NAGAR HAVELI         87
# State - MAHARASHTRA                  87
# State - ANDHRA PRADESH               87
# State - KARNATAKA                    87
# State - GOA                          87
# State - LAKSHADWEEP                  87
# State - KERALA                       87
# State - TAMIL NADU                   87
# State - PUDUCHERRY                   87
# State - WEST BENGAL                  87
# State - ASSAM                        87
# State - MEGHALAYA                    87
# State - RAJASTHAN                    87
# State - HIMACHAL PRADESH             87
# State - PUNJAB                       87
# ...

# %%
plt.figure(figsize=(20,20))
sns.barplot(data=df, x = df["Area_Name"], y = "Literate_Persons")
# Rotate the x-axis labels
plt.xticks(rotation=45)  # Rotate by 45 degrees

plt.show()

# %%
plt.figure(figsize=(20,20))
sns.boxplot(data=df, x = df["Area_Name"], y = "Illiterate_Females")
# Rotate the x-axis labels
plt.xticks(rotation=45)  # Rotate by 45 degrees

plt.show()
