# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tendulkar_ODI.csv")

# %%
df
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1    0    -    2   0  0       0   5    caught    2
# 1             2    0    2    2   0  0       0   5    caught    2
# 2             3   36   51   39   5  0    92.3   6    caught    1
# 3             4   19   38   35   1  1   54.28   4    bowled    2
# 4             5   31   31   26   3  0  119.23   6    bowled    2
# ..          ...  ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291   18   21   14   2  0  128.57   2    caught    2
# 291         292    2    9    6   0  0   33.33   2    caught    2
# 292         293    3   21   12   0  0      25   2    caught    2
# 293         294   14   34   15   2  0   93.33   2   run out    2
# 294         295  114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date
# 0       v Pakistan  Gujranwala  18-Dec-89
# 1    v New Zealand     Dunedin   1-Mar-90
# 2    v New Zealand  Wellington   6-Mar-90
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  295 non-null    int64
#  1   Runs        295 non-null    object
#  2   Mins        295 non-null    object
#  3   BF          295 non-null    object
#  4   4s          295 non-null    object
#  5   6s          295 non-null    object
#  6   SR          295 non-null    object
#  7   Pos         295 non-null    object
#  8   Dismissal   295 non-null    object
#  9   Inns        295 non-null    object
#  10  Opposition  295 non-null    object
#  11  Ground      295 non-null    object
#  12  Start Date  295 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 30.1+ KB

# %%
df["Runs"]=df["Runs"].str.replace("*", "")

# %%
df["Runs"] = df["Runs"].astype("int32")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df["Runs"] = df["Runs"].astype("int32")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
# ...

# %%
df["Runs"] = pd.to_numeric(df["Runs"], errors='coerce')

# %%
df["Runs"].fillna(0, inplace=True)

# %%
df["Runs"] = df["Runs"].astype("int32")

# %%
run_frequency= df["Runs"].value_counts().sort_index()

# %%
sns.barplot(x=run_frequency, y=df["Runs"])
# Out:
# <Axes: xlabel='count', ylabel='Runs'>

# %%
# Step 1: Create a frequency distribution of the 'Runs' column
runs_frequency = df["Runs"].value_counts().sort_index()

# Step 2: Plot the bar chart
plt.figure(figsize=(10, 6))
runs_frequency.plot(kind='bar', color='skyblue')

# Step 3: Add labels and title
plt.xlabel('Runs Scored')
plt.ylabel('Frequency')
plt.title('Frequency of Runs Scored')
plt.xticks(rotation=0)

# Show the plot
plt.show()

# Step 4: Identify the bucket with the most frequent score
most_frequent_score = runs_frequency.idxmax()
most_frequent_count = runs_frequency.max()

# %%
df
# Out:
#      Unnamed: 0  Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1     0    -    2   0  0       0   5    caught    2
# 1             2     0    2    2   0  0       0   5    caught    2
# 2             3    36   51   39   5  0    92.3   6    caught    1
# 3             4    19   38   35   1  1   54.28   4    bowled    2
# 4             5    31   31   26   3  0  119.23   6    bowled    2
# ..          ...   ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291    18   21   14   2  0  128.57   2    caught    2
# 291         292     2    9    6   0  0   33.33   2    caught    2
# 292         293     3   21   12   0  0      25   2    caught    2
# 293         294    14   34   15   2  0   93.33   2   run out    2
# 294         295   114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date
# 0       v Pakistan  Gujranwala  18-Dec-89
# 1    v New Zealand     Dunedin   1-Mar-90
# 2    v New Zealand  Wellington   6-Mar-90
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  295 non-null    int64
#  1   Runs        295 non-null    int32
#  2   Mins        295 non-null    object
#  3   BF          295 non-null    object
#  4   4s          295 non-null    object
#  5   6s          295 non-null    object
#  6   SR          295 non-null    object
#  7   Pos         295 non-null    object
#  8   Dismissal   295 non-null    object
#  9   Inns        295 non-null    object
#  10  Opposition  295 non-null    object
#  11  Ground      295 non-null    object
#  12  Start Date  295 non-null    object
# dtypes: int32(1), int64(1), object(11)
# memory usage: 28.9+ KB

# %%
#df["4s"] = df["4s"].astype("int32")

# %%
df["4s"]=df["4s"].str.replace("-", "0")

# %%
df["4s"] = df["4s"].astype("int32")

# %%
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
df["4s"].value_counts()
# Out:
# 4s
# 0     72
# 1     37
# 2     29
# 3     25
# 4     17
# 5     16
# 9     15
# 6     14
# 8     13
# 7     13
# 10    11
# 13     8
# 12     5
# 15     4
# 11     4
# 16     4
# 14     3
# 19     2
# 20     1
# 17     1
# 25     1
# Name: count, dtype: int64
