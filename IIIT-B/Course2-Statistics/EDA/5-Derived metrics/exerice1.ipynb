# %%
import pandas as pd

# %%
df =pd.read_csv("odi-batting.csv")

# %%
df.columns
# Out:
# Index(['Country', 'Player', 'Runs', 'MatchDate', 'Weekday', 'Ground', 'Versus',
#        'Balls'],
#       dtype='object')

# %%
newdf= df[df["Runs"] >=100]

# %%
newdf["Strike_rate"] = (newdf["Runs"] / newdf["Balls"])
# Out:
# /tmp/ipykernel_47334/465054081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf["Strike_rate"] = (newdf["Runs"] / newdf["Balls"])

# %%
df_sorted = newdf.sort_values(by="Strike_rate", ascending= False)

# %%
df_sorted
# Out:
#             Country                     Player  Runs   MatchDate Weekday  \
# 28157      Pakistan              Shahid Afridi   102  04-10-1996     Fri
# 28158      Pakistan              Shahid Afridi   102  15-04-2005     Fri
# 34446  South Africa             Mark V Boucher   147  20-09-2006     Wed
# 28153      Pakistan              Shahid Afridi   124  21-06-2010     Mon
# 36753     Sri Lanka        Sanath T Jayasuriya   134  02-04-1996     Tue
# ...             ...                        ...   ...         ...     ...
# 28851      Pakistan                 Ramiz Raja   102  23-02-1992     Sun
# 24821   New Zealand             Glenn M Turner   114  14-06-1975     Sat
# 43594   West Indies  Cuthbert Gordon Greenidge   103  21-11-1981     Sat
# 43591   West Indies  Cuthbert Gordon Greenidge   106  09-06-1979     Sat
# 2141      Australia               David C Boon   102  10-12-1991     Tue
#
#                                      Ground       Versus  Balls  Strike_rate
# ...

# %%
df1= newdf[newdf["Country"] == "India"]

# %%
df1['MatchDate'] = pd.to_datetime(df['MatchDate'], format='%d-%m-%Y')
# Out:
# /tmp/ipykernel_47334/1893616899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MatchDate'] = pd.to_datetime(df['MatchDate'], format='%d-%m-%Y')

# %%
df1['Year'] = df1['MatchDate'].dt.year
# Out:
# /tmp/ipykernel_47334/4268976981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Year'] = df1['MatchDate'].dt.year

# %%
df1
# Out:
#       Country              Player  Runs  MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200 2010-02-24     Wed
# 13602   India  Sachin R Tendulkar   186 1999-11-08     Mon
# 13603   India  Sachin R Tendulkar   175 2009-11-05     Thu
# 13604   India  Sachin R Tendulkar   163 2009-03-08     Sun
# 13605   India  Sachin R Tendulkar   152 2003-02-23     Sun
# ...       ...                 ...   ...        ...     ...
# 18180   India      Yusuf K Pathan   123 2010-12-07     Tue
# 18181   India      Yusuf K Pathan   105 2011-01-23     Sun
# 18244   India         Raman Lamba   102 1986-10-07     Tue
# 18467   India    Woorkeri V Raman   114 1992-12-11     Fri
# 18636   India       Chetan Sharma   101 1989-10-25     Wed
#
#                                    Ground        Versus  Balls  Strike_rate  \
# 13601          Captain Roop Singh Stadium  South Africa    147     1.360544
# 13602         Lal Bahadur Shastri Stadium   New Zealand    150     1.240000
# ...

# %%
df1["Year"].value_counts()
# Out:
# Year
# 1998    18
# 1999    15
# 2009    13
# 2010    12
# 2005    11
# 2008    10
# 2003    10
# 2000    10
# 2001     9
# 2002     9
# 1996     8
# 2011     8
# 1994     7
# 1997     7
# 2004     7
# 2006     5
# 2007     5
# 1988     5
# 1987     4
# 1990     3
# 1984     3
# 1993     2
# 1989     2
# 1986     2
# 1991     2
# 1995     1
# 1983     1
# 1992     1
# Name: count, dtype: int64
