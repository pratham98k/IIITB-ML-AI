# %%
import pandas as pd

# %%
df = pd.read_csv("telecom_churn.csv")

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.size
# Out:
# 66660

# %%
telecom_churn.columns.to_list()
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
#'O' 'Object'
df.describe(include='O')
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
#all
df.describe(include='all')
# Out:
#        State  Account length    Area code International plan Voice mail plan  \
# count   3333     3333.000000  3333.000000               3333            3333
# unique    51             NaN          NaN                  2               2
# top       WV             NaN          NaN                 No              No
# freq     106             NaN          NaN               3010            2411
# mean     NaN      101.064806   437.182418                NaN             NaN
# std      NaN       39.822106    42.371290                NaN             NaN
# min      NaN        1.000000   408.000000                NaN             NaN
# 25%      NaN       74.000000   408.000000                NaN             NaN
# 50%      NaN      101.000000   415.000000                NaN             NaN
# 75%      NaN      127.000000   510.000000                NaN             NaN
# max      NaN      243.000000   510.000000                NaN             NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
# Value_count = count of values present in particular colum ( categroical)
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
df['Churn'].value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
df['State'].value_counts()
# Out:
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64

# %%
df['Area code'].value_counts()
# Out:
# Area code
# 415    1655
# 510     840
# 408     838
# Name: count, dtype: int64

# %%
df['Area code'].value_counts(normalize=True)*100
# Out:
# Area code
# 415    49.654965
# 510    25.202520
# 408    25.142514
# Name: proportion, dtype: float64

# %%
df['Churn'].value_counts(normalize=True)*100
# Out:
# Churn
# False    85.508551
# True     14.491449
# Name: proportion, dtype: float64

# %%
(df['Churn'].value_counts()/df.shape[0])*100
# Out:
# Churn
# False    85.508551
# True     14.491449
# Name: count, dtype: float64

# %%
#method1: use[] breackets

# %%
type(df['Churn'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #method with 2

# %%
df.iloc[3]
# Out:
# State                        OH
# Account length               84
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         299.4
# Total day calls              71
# Total day charge           50.9
# Total eve minutes          61.9
# Total eve calls              88
# Total eve charge           5.26
# Total night minutes       196.9
# Total night calls            89
# Total night charge         8.86
# Total intl minutes          6.6
# Total intl calls              7
# Total intl charge          1.78
# Customer service calls        2
# Churn                     False
# Name: 3, dtype: object

# %%
df.iloc[356]
# Out:
# State                        CA
# Account length              124
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         244.6
# Total day calls              89
# Total day charge          41.58
# Total eve minutes         188.8
# Total eve calls              80
# Total eve charge          16.05
# Total night minutes       206.0
# Total night calls           114
# Total night charge         9.27
# Total intl minutes         11.3
# Total intl calls              4
# Total intl charge          3.05
# Customer service calls        1
# Churn                     False
# Name: 356, dtype: object

# %%
#sub set data using iolic : iloc[n1:n2, n1:m2]
#n1:n2 -----> rows n1 = start, n2= n2-1 (end)
#m1:m2 ------> colums m1 = start,

# %%
df.iloc[3:8]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
# 6                     24              218.2               88
# 7                      0              157.0               79
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3             50.90               61.9               88              5.26
# ...

# %%
df.iloc[3:8, 0:4]
# Out:
#   State  Account length  Area code International plan
# 3    OH              84        408                Yes
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes
# 6    MA             121        510                 No
# 7    MO             147        415                Yes

# %%
df.iloc[:10,:3].describe()
# Out:
#        Account length   Area code
# count       10.000000   10.000000
# mean       117.500000  432.600000
# std         23.486403   40.893357
# min         75.000000  408.000000
# 25%        109.500000  415.000000
# 50%        119.500000  415.000000
# 75%        134.750000  415.000000
# max        147.000000  510.000000

# %%
df.iloc[3:,2:8]
# Out:
#       Area code International plan Voice mail plan  Number vmail messages  \
# 3           408                Yes              No                      0
# 4           415                Yes              No                      0
# 5           510                Yes              No                      0
# 6           510                 No             Yes                     24
# 7           415                Yes              No                      0
# ...         ...                ...             ...                    ...
# 3328        415                 No             Yes                     36
# 3329        415                 No              No                      0
# 3330        510                 No              No                      0
# 3331        510                Yes              No                      0
# 3332        415                 No             Yes                     25
#
#       Total day minutes  Total day calls
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.loc[2:8, ['Total eve calls', 'Total eve charge,']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.loc[2:8, ['Total eve calls', 'Total eve charge,']]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1339, in _LocIndexer._getitem_tuple(self, tup)
#    1336 if self._multi_take_opportunity(tup):
#    1337     return self._multi_take(tup)
# -> 1339 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df[df['Churn']==True]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
import numpy as np

# %%
#Create an array of first 10 multiples of 5 using the 'arange' function.
#x2 = [(n ** power) % modulo for n in np.arange(8)]

# %%
x2=[(n *5) for n in np.arange(1,11)]

# %%
np.array(x2)
# Out:
# array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# %%
type(x2)
# Out:
# list

# %%
np.ones((2,2),dtype=int)
# Out:
# array([[1, 1],
#        [1, 1]])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 np.ones(np.zeros((2,2)))
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/core/numeric.py:191, in ones(shape, dtype, order, like)
#     188 if like is not None:
#     189     return _ones_with_like(like, shape, dtype=dtype, order=order)
# --> 191 a = empty(shape, dtype, order)
#     192 multiarray.copyto(a, 1, casting='unsafe')
#     193 return a
#
# TypeError: only integer scalar arrays can be converted to a scalar index
